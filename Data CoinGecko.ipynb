# %% [markdown]
# <a href="https://colab.research.google.com/github/TauqeerSaleem/K-Mean-Clustering-for-Cryptos/blob/main/Data%20CoinGecko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json

url = 'https://api.coingecko.com/api/v3/coins/list'
response = requests.get(url)
if response.status_code != 200:
    print("Unable to Connect!")
else:
    crypto_list = pd.DataFrame(json.loads(response.text))
    data = pd.DataFrame()
    for i in range (len(crypto_list['symbol'])):
        coin_id = crypto_list['id'][i]
        coin_symbol = crypto_list['symbol'][i]
        # USDT, DAI, UST not included
        if coin_symbol not in ['usdt', 'dai', 'ust']:
            print(f'{i} id: {coin_id}, symbol: {coin_symbol}') 
            url = f'https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range?vs_currency=usd&from=1604170800&to=1636570800'
            response = requests.get(url)
            if response.status_code == 200:
                temp = pd.DataFrame(json.loads(response.text))
                temp.insert(0, 'Symbol', coin_symbol)
                data = data.append(temp)
            else:
                print(f'===============NO RESPONSE FOR: {coin_symbol}')
    
    data.index = [i for i in range(len(data))]
    data.insert(1, 'Date', 0)
    data.insert(2, 'Price', 0)
    data.insert(3, 'Market Capital', 0)
    data.insert(4, 'Total Volume', 0)
    
    for i in range(len(data)):
        data.loc[i, 'Date'] = pd.to_datetime(data.loc[i, 'prices'][0], 
                                         unit ='ms')
        data.loc[i, 'Price'] = data['prices'][i][1]
        data.loc[i, 'Market Capital'] = data.loc[i, 'market_caps'][1]
        data.loc[i, 'Total Volume'] = data.loc[i, 'total_volumes'][1]
    
    data['Date'] = pd.to_datetime(data['Date'], format = '%Y-%m-%d')
    data.index = data['Date']
    
    del data['Date']
    del data['prices']
    del data['market_caps']
    del data['total_volumes']
    
    data.to_csv("Crypto_data.csv", index = True)
# Out:
# ===============NO RESPONSE FOR: bee
# 1202 id: beefy-finance, symbol: bifi
# ===============NO RESPONSE FOR: bifi
# 1203 id: beekan, symbol: bkbt
# ===============NO RESPONSE FOR: bkbt
# 1204 id: beenode, symbol: bnode
# ===============NO RESPONSE FOR: bnode
# 1205 id: beer-inu, symbol: beer
# ===============NO RESPONSE FOR: beer
# 1206 id: beer-money, symbol: beer
# ===============NO RESPONSE FOR: beer
# 1207 id: beethoven-x, symbol: beets
# ===============NO RESPONSE FOR: beets
# 1208 id: beetle-coin, symbol: beet
# ===============NO RESPONSE FOR: beet
# 1209 id: beetr, symbol: btr
# ===============NO RESPONSE FOR: btr
# 1210 id: beholder, symbol: eye
# ===============NO RESPONSE FOR: eye
# 1211 id: bela, symbol: aqua
# ===============NO RESPONSE FOR: aqua
# 1212 id: beldex, symbol: bdx
# ===============NO RESPONSE FOR: bdx
# 1213 id: believer, symbol: blvr
# ===============NO RESPONSE FOR: blvr
# 1214 id: belifex, symbol: befx
# ===============NO RESPONSE FOR: befx
# 1215 id: bella-protocol, symbol: bel
# ===============NO RESPONSE FOR: bel
# 1216 id: bellcoin, symbol: bell
# ===============NO RESPONSE FOR: bell
# 1217 id: belrium, symbol: bel
# ===============NO RESPONSE FOR: bel
# 1218 id: belt, symbol: belt
# ===============NO RESPONSE FOR: belt
# 1219 id: beluga-fi, symbol: beluga
# ===============NO RESPONSE FOR: beluga
# 1220 id: benative, symbol: bnv
# ===============NO RESPONSE FOR: bnv
# 1221 id: benchmark-protocol, symbol: mark
# ===============NO RESPONSE FOR: mark
# 1222 id: benepit, symbol: bnp
# ===============NO RESPONSE FOR: bnp
# 1223 id: benqi, symbol: qi
# ===============NO RESPONSE FOR: qi
# 1224 id: benzene, symbol: bzn
# ===============NO RESPONSE FOR: bzn
# 1225 id: beowulf, symbol: bwf
# ===============NO RESPONSE FOR: bwf
# 1226 id: bep20-leo, symbol: bLEO
# ===============NO RESPONSE FOR: bLEO
# 1227 id: bepro-network, symbol: bepro
# ===============NO RESPONSE FOR: bepro
# 1228 id: bernard, symbol: bern
# ===============NO RESPONSE FOR: bern
# 1229 id: berry, symbol: Berry
# ===============NO RESPONSE FOR: Berry
# 1230 id: berry-data, symbol: bry
# ===============NO RESPONSE FOR: bry
# 1231 id: berryswap, symbol: berry
# ===============NO RESPONSE FOR: berry
# 1232 id: berry-vault-nftx, symbol: berry
# ===============NO RESPONSE FOR: berry
# 1233 id: berserk-inu, symbol: berserk
# ===============NO RESPONSE FOR: berserk
# 1234 id: beshare-token, symbol: bst
# ===============NO RESPONSE FOR: bst
# 1235 id: bestay, symbol: bsy
# ===============NO RESPONSE FOR: bsy
# 1236 id: beta-finance, symbol: beta
# ===============NO RESPONSE FOR: beta
# 1237 id: betapulsartoken, symbol: bpul
# ===============NO RESPONSE FOR: bpul
# 1238 id: betdice, symbol: dice
# ===============NO RESPONSE FOR: dice
# 1239 id: betherchip, symbol: bec
# ===============NO RESPONSE FOR: bec
# 1240 id: bethereum, symbol: bether
# ===============NO RESPONSE FOR: bether
# 1241 id: betller-coin, symbol: btllr
# ===============NO RESPONSE FOR: btllr
# 1242 id: betrium, symbol: btrm
# ===============NO RESPONSE FOR: btrm
# 1243 id: betswamp, symbol: bets
# ===============NO RESPONSE FOR: bets
# 1244 id: better-money, symbol: better
# ===============NO RESPONSE FOR: better
# 1245 id: betu, symbol: betu
# ===============NO RESPONSE FOR: betu
# 1246 id: betxoin, symbol: betxc
# ===============NO RESPONSE FOR: betxc
# 1247 id: beverage, symbol: beverage
# ===============NO RESPONSE FOR: beverage
# 1248 id: beverage-token, symbol: drink
# ===============NO RESPONSE FOR: drink
# 1249 id: bevo-digital-art-token, symbol: bevo
# ===============NO RESPONSE FOR: bevo
# 1250 id: beyondcoin, symbol: bynd
# ===============NO RESPONSE FOR: bynd
# 1251 id: beyond-finance, symbol: byn
# ===============NO RESPONSE FOR: byn
# 1252 id: beyond-protocol, symbol: bp
# ===============NO RESPONSE FOR: bp
# 1253 id: beyond-the-scene-coin, symbol: btsc
# ===============NO RESPONSE FOR: btsc
# 1254 id: bezant, symbol: bznt
# ===============NO RESPONSE FOR: bznt
# 1255 id: bezoge-earth, symbol: bezoge
# ===============NO RESPONSE FOR: bezoge
# 1256 id: bezop, symbol: bez
# ===============NO RESPONSE FOR: bez
# 1257 id: bfg-token, symbol: bfg
# ===============NO RESPONSE FOR: bfg
# 1258 id: bficoin, symbol: bfic
# ===============NO RESPONSE FOR: bfic
# 1259 id: bfk-warzone, symbol: bfk
# ===============NO RESPONSE FOR: bfk
# 1260 id: bgan-vault-nftx, symbol: bgan
# ===============NO RESPONSE FOR: bgan
# 1261 id: bgogo, symbol: bgg
# ===============NO RESPONSE FOR: bgg
# 1262 id: bgov, symbol: bgov
# ===============NO RESPONSE FOR: bgov
# 1263 id: bgt, symbol: bgt
# ===============NO RESPONSE FOR: bgt
# 1264 id: bholdus-token, symbol: bho
# ===============NO RESPONSE FOR: bho
# 1265 id: biblepay, symbol: bbp
# ===============NO RESPONSE FOR: bbp
# 1266 id: bibox-token, symbol: bix
# ===============NO RESPONSE FOR: bix
# 1267 id: biconomy-exchange-token, symbol: bit
# ===============NO RESPONSE FOR: bit
# 1268 id: bidao, symbol: bid
# ===============NO RESPONSE FOR: bid
# 1269 id: bidcommerce, symbol: bidcom
# ===============NO RESPONSE FOR: bidcom
# 1270 id: biden, symbol: biden
# ===============NO RESPONSE FOR: biden
# 1271 id: bidesk, symbol: bdk
# ===============NO RESPONSE FOR: bdk
# 1272 id: bidipass, symbol: bdp
# ===============NO RESPONSE FOR: bdp
# 1273 id: bifi, symbol: bifi
# ===============NO RESPONSE FOR: bifi
# 1274 id: bifrost, symbol: bfc
# ===============NO RESPONSE FOR: bfc
# 1275 id: bifrost-native-coin, symbol: bnc
# ===============NO RESPONSE FOR: bnc
# 1276 id: bigbang-core, symbol: bbc
# ===============NO RESPONSE FOR: bbc
# 1277 id: bigbang-game, symbol: bbgc
# ===============NO RESPONSE FOR: bbgc
# 1278 id: big-beautiful-women, symbol: bbw
# ===============NO RESPONSE FOR: bbw
# 1279 id: bigbom-eco, symbol: bbo
# ===============NO RESPONSE FOR: bbo
# 1280 id: bigcash, symbol: bgc
# ===============NO RESPONSE FOR: bgc
# 1281 id: bigdata-cash, symbol: bdcash
# ===============NO RESPONSE FOR: bdcash
# 1282 id: big-data-protocol, symbol: bdp
# ===============NO RESPONSE FOR: bdp
# 1283 id: big-defi-energy, symbol: bde
# ===============NO RESPONSE FOR: bde
# 1284 id: big-digital-shares, symbol: bds
# ===============NO RESPONSE FOR: bds
# 1285 id: big-eth, symbol: bigeth
# ===============NO RESPONSE FOR: bigeth
# 1286 id: bigfoot, symbol: foot
# ===============NO RESPONSE FOR: foot
# 1287 id: big-league, symbol: bglg
# ===============NO RESPONSE FOR: bglg
# 1288 id: bigo-token, symbol: bigo
# ===============NO RESPONSE FOR: bigo
# 1289 id: bigshortbets, symbol: bigsb
# ===============NO RESPONSE FOR: bigsb
# 1290 id: biitgatti, symbol: bitgatti
# ===============NO RESPONSE FOR: bitgatti
# 1291 id: biki, symbol: biki
# ===============NO RESPONSE FOR: biki
# 1292 id: bilaxy-token, symbol: bia
# ===============NO RESPONSE FOR: bia
# 1293 id: bilira, symbol: tryb
# ===============NO RESPONSE FOR: tryb
# 1294 id: billionhappiness, symbol: bhc
# ===============NO RESPONSE FOR: bhc
# 1295 id: bill-token, symbol: bill
# ===============NO RESPONSE FOR: bill
# 1296 id: bimcoin, symbol: bim
# ===============NO RESPONSE FOR: bim
# 1297 id: bimp-finance, symbol: bimp
# ===============NO RESPONSE FOR: bimp
# 1298 id: binahunter, symbol: bhunt
# ===============NO RESPONSE FOR: bhunt
# 1299 id: binamars, symbol: bmars
# ===============NO RESPONSE FOR: bmars
# 1300 id: binamars-game, symbol: bgame
# ===============NO RESPONSE FOR: bgame
# 1301 id: binamon, symbol: bmon
# ===============NO RESPONSE FOR: bmon
# 1302 id: binance8, symbol: b8
# ===============NO RESPONSE FOR: b8
# 1303 id: binance-agile-set-dollar, symbol: basd
# ===============NO RESPONSE FOR: basd
# 1304 id: binance-bitcoin, symbol: btcb
# ===============NO RESPONSE FOR: btcb
# 1305 id: binancecoin, symbol: bnb
# ===============NO RESPONSE FOR: bnb
# 1306 id: binancedog, symbol: bidog
# ===============NO RESPONSE FOR: bidog
# 1307 id: binance-ecosystem-value, symbol: bev
# ===============NO RESPONSE FOR: bev
# 1308 id: binance-eth, symbol: beth
# ===============NO RESPONSE FOR: beth
# 1309 id: binanceidr, symbol: bidr
# ===============NO RESPONSE FOR: bidr
# 1310 id: binance-peg-avalanche, symbol: avax
# ===============NO RESPONSE FOR: avax
# 1311 id: binance-peg-bitcoin-cash, symbol: bch
# ===============NO RESPONSE FOR: bch
# 1312 id: binance-peg-cardano, symbol: ada
# ===============NO RESPONSE FOR: ada
# 1313 id: binance-peg-dogecoin, symbol: doge
# ===============NO RESPONSE FOR: doge
# 1314 id: binance-peg-eos, symbol: eos
# ===============NO RESPONSE FOR: eos
# 1315 id: binance-peg-filecoin, symbol: fil
# ===============NO RESPONSE FOR: fil
# 1316 id: binance-peg-firo, symbol: firo
# ===============NO RESPONSE FOR: firo
# 1317 id: binance-peg-iotex, symbol: iotx
# ===============NO RESPONSE FOR: iotx
# 1318 id: binance-peg-litecoin, symbol: ltc
# ===============NO RESPONSE FOR: ltc
# 1319 id: binance-peg-ontology, symbol: ont
# ===============NO RESPONSE FOR: ont
# 1320 id: binance-peg-polkadot, symbol: dot
# ===============NO RESPONSE FOR: dot
# 1321 id: binance-peg-xrp, symbol: xrp
# ===============NO RESPONSE FOR: xrp
# 1322 id: binance-smart-chain-girl, symbol: bscgirl
# ===============NO RESPONSE FOR: bscgirl
# 1323 id: binance-usd, symbol: busd
# ===============NO RESPONSE FOR: busd
# 1324 id: binance-vnd, symbol: bvnd
# ===============NO RESPONSE FOR: bvnd
# 1325 id: binance-wrapped-btc, symbol: bbtc
# ===============NO RESPONSE FOR: bbtc
# 1326 id: binanomics, symbol: bnm
# ===============NO RESPONSE FOR: bnm
# 1327 id: binapet, symbol: bpet
# ===============NO RESPONSE FOR: bpet
# 1328 id: binarium, symbol: bin
# ===============NO RESPONSE FOR: bin
# 1329 id: binaryx, symbol: bnx
# ===============NO RESPONSE FOR: bnx
# 1330 id: bincentive, symbol: bcnt
# ===============NO RESPONSE FOR: bcnt
# 1331 id: binemon, symbol: bin
# ===============NO RESPONSE FOR: bin
# 1332 id: bingo-cash, symbol: bgo
# ===============NO RESPONSE FOR: bgo
# 1333 id: bingo-share, symbol: sbgo
# ===============NO RESPONSE FOR: sbgo
# 1334 id: bingus-network, symbol: bingus
# ===============NO RESPONSE FOR: bingus
# 1335 id: binjit-coin, symbol: bnj
# ===============NO RESPONSE FOR: bnj
# 1336 id: binom-protocol, symbol: binom
# ===============NO RESPONSE FOR: binom
# 1337 id: binosaurs, symbol: binosaurs
# ===============NO RESPONSE FOR: binosaurs
# 1338 id: binstarter, symbol: bsr
# ===============NO RESPONSE FOR: bsr
# 1339 id: bintex-futures, symbol: bntx
# ===============NO RESPONSE FOR: bntx
# 1340 id: biocrypt, symbol: bio
# ===============NO RESPONSE FOR: bio
# 1341 id: biokkoin, symbol: bkkg
# ===============NO RESPONSE FOR: bkkg
# 1342 id: biopassport, symbol: biot
# ===============NO RESPONSE FOR: biot
# 1343 id: biopset, symbol: biop
# ===============NO RESPONSE FOR: biop
# 1344 id: bios, symbol: bios
# ===============NO RESPONSE FOR: bios
# 1345 id: biotron, symbol: btrn
# ===============NO RESPONSE FOR: btrn
# 1346 id: bip, symbol: bip
# ===============NO RESPONSE FOR: bip
# 1347 id: birake, symbol: bir
# ===============NO RESPONSE FOR: bir
# 1348 id: birb, symbol: birb
# ===============NO RESPONSE FOR: birb
# 1349 id: birdchain, symbol: bird
# ===============NO RESPONSE FOR: bird
# 1350 id: bird-money, symbol: bird
# ===============NO RESPONSE FOR: bird
# 1351 id: birdy-finance, symbol: bird
# ===============NO RESPONSE FOR: bird
# 1352 id: birthday-cake, symbol: bday
# ===============NO RESPONSE FOR: bday
# 1353 id: bishares, symbol: bison
# ===============NO RESPONSE FOR: bison
# 1354 id: bishoku-inu, symbol: bishoku
# ===============NO RESPONSE FOR: bishoku
# 1355 id: bishu-finance, symbol: bishufi
# ===============NO RESPONSE FOR: bishufi
# 1356 id: bismuth, symbol: bis
# ===============NO RESPONSE FOR: bis
# 1357 id: bistroo, symbol: bist
# ===============NO RESPONSE FOR: bist
# 1358 id: biswap, symbol: bsw
# ===============NO RESPONSE FOR: bsw
# 1359 id: biswap-token, symbol: biswap
# ===============NO RESPONSE FOR: biswap
# 1360 id: bit2me, symbol: b2m
# 1361 id: bitacium, symbol: xbond
# 1362 id: bitalgo, symbol: alg
# 1363 id: bitant, symbol: bitant
# 1364 id: bitau, symbol: bau
# 1365 id: bitball, symbol: btb
# 1366 id: bitball-treasure, symbol: btrs
# 1367 id: bitbar, symbol: btb
# 1368 id: bitbase-token, symbol: btbs
# 1369 id: bitberry-token, symbol: bbr
# 1370 id: bitblocks-finance, symbol: bbkfi
# 1371 id: bitblocks-project, symbol: bbk
# 1372 id: bitbook-gambling, symbol: bxk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b795b33af97a> in <module>()
#      17             print(f'{i} id: {coin_id}, symbol: {coin_symbol}')
#      18             url = f'https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range?vs_currency=usd&from=1604170800&to=1636570800'
# ---> 19             response = requests.get(url)
#      20             if response.status_code == 200:
#      21                 temp = pd.DataFrame(json.loads(response.text))
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
